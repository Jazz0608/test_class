# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## python數學運算

# %%
print("這是我的第一個函式")
print('這是我的第2個函式')
print(50)
print(50.0)
# Out:
# 這是我的第一個函式
# 這是我的第2個函式
# 50
# 50.0

# %%
print("這是整數",50)
print("這是浮點數", 50.5)
print("這是字串", 'jazz')
print("這是布林值", True)
print("這是布林值", False)
