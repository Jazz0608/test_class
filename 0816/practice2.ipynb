# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## python數學運算

# %%
print("這是我的第一個函式")
print('這是我的第2個函式')
print(50)
print(50.0)
# Out:
# 這是我的第一個函式
# 這是我的第2個函式
# 50
# 50.0

# %%
print("這是整數",50)
print("這是浮點數", 50.5)
print("這是字串", 'jazz')
print("這是布林值", True)
print("這是布林值", False)
# Out:
# 這是整數 50
# 這是浮點數 50.5
# 這是字串 jazz
# 這是布林值 True
# 這是布林值 False

# %%
print(3+5)
print(3+5+10)
print(3+5*2)
print((3+5)*2)
print(99**99)
# Out:
# 8
# 18
# 13
# 16
# 369729637649726772657187905628805440595668764281741102430259972423552570455277523421410650010128232727940978889548326540119429996769494359451621570193644014418071060667659301384999779999159200499899

# %%
print(int("5")+5)
# Out:
# 10

# %%
a=int(input("請輸入整數:"))
b=float(input("請輸入一個浮點數:"))
print(a,"*",b,"=", a*b)
# Out:
# 請輸入整數: 2
# 請輸入一個浮點數: 3
# 2 * 3.0 = 6.0

# %%
radius=float(input("請輸入半徑:")) #半徑
area = radius ** 2 * 3.1415926 #半徑x半徑x3.1415926
print("半徑",radius,", 圓面積=", area)
# Out:
# 請輸入半徑: 10
# 半徑 10.0 , 圓面積= 314.15926

# %%
import math

radius=float(input("請輸入半徑:")) #半徑
area = radius ** 2 * math.pi #半徑x半徑x3.1415926
print("半徑",radius,", 圓面積=", area)
# Out:
# 請輸入半徑: 10
# 半徑 10.0 , 圓面積= 314.1592653589793
