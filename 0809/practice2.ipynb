# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空會呈現藍色，主要是因為一個物理現象，叫做**「瑞利散射」（Rayleigh scattering）**。
#
# 我們可以把這個過程拆解成以下三個簡單的步驟來理解：
#
# ### 1. 陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實包含了彩虹的所有顏色（紅、橙、黃、綠、藍、靛、紫）。這些光以「波」的形式傳播：
# *   **紅光、橙光**的波長比較**長**。
# *   **藍光、紫光**的波長比較**短**。
#
# ### 2. 大氣層的「阻礙」
# 當陽光穿過地球的大氣層時，會遇到無數的氣體分子（主要是氮氣和氧氣）和微小的塵埃。
# *   波長較**長**的光（如紅光、黃光）像大卡車一樣，可以直接穿透這些微小的氣體分子，直達地面。
# *   波長較**短**的光（如藍光、紫光）則像小兵遇到障礙物，很容易被這些氣體分子撞得**向四面八方散射開來**。
#
# 因為藍光在空氣中被到處亂撞、灑滿整個天空，所以當我們抬頭看天空時，就會看到滿天的藍光。
#
# ---
#
# ### 💡 常見疑問：為什麼天空不是「紫色」的？
# 紫光的波長比藍光還要短，照理說應該散射得更厲害，那為什麼天空不是紫色的？原因有兩個：
#
# 1.  **太陽光的成分**：太陽放射出來的光芒中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的構造**：人類眼睛的視網膜上，負責接收顏色的錐狀細胞對「藍色」的敏感度遠高於「紫色」。所以，即使天空有一些紫光，我們的大腦還是會把它解讀為藍色。
#
# ---
#
# ### 補充：為什麼傍晚的夕陽是「紅色」的？
# 到了黃昏時，太陽的角度很低，陽光必須穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
#
# 在這段漫長的旅程中，幾乎所有的藍光在半路就已經被散射光了，只剩下穿透力最強、波長最長的**紅光和橙光**能夠到達我們的眼睛，因此夕陽看起來就是美麗的橘紅色。
