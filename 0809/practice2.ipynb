# %%
from google import genai

client = genai.client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from google import genai
#       2
# ----> 3 client = genai.client.interactions.create(
#       4     model="gemini-3.5-flash",
#       5     input="天空為什麼是藍的"
#       6 )
#
# AttributeError: module 'google.genai.client' has no attribute 'interactions'
